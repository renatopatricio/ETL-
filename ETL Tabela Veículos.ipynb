# %% [markdown]
# # ETL da tabela Veículos

# %%
import pandas as pd
import numpy as np

# %%
dados = dados = pd.read_csv('Tabela - Veículos.csv', sep = ',')   
dados
# Out:
#    ID veículos         Tipo      Status
# 0        VEH01        carro     Ocupado
# 1        VEH02        carro     Ocupado
# 2        VEH03  caminhonete     Ocupado
# 3        VEH04  caminhonete     Ocupado
# 4        VEH05        carro     Ocupado
# 5        VEH06         moto     Ocupado
# 6        VEH07        carro     Ocupado
# 7        VEH08         moto     Ocupado
# 8        VEH09  caminhonete     Ocupado
# 9        VEH10         moto     Ocupado
# 10       VEH11         moto     Ocupado
# 11       VEH12        carro     Ocupado
# 12       VEH13         moto     Ocupado
# 13       VEH14         moto     Ocupado
# 14       VEH15  caminhonete     Ocupado
# 15       VEH16  caminhonete     Ocupado
# 16       VEH17  caminhonete     Ocupado
# 17       VEH18         moto     Ocupado
# 18       VEH19        carro     Ocupado
# 19       VEH20        carro     Ocupado
# 20       VEH21  caminhonete     Ocupado
# 21       VEH22        carro     Ocupado
# ...

# %% [markdown]
# ## Contando a quantidade por tipo de veículo e o status total

# %%
dados.value_counts("Tipo")
# Out:
# Tipo
# caminhonete    18
# carro          18
# moto           14
# dtype: int64

# %%
dados.value_counts("Status")
# Out:
# Status
# Ocupado       42
# Disponível     8
# dtype: int64

# %%
Total = dados['ID veículos'].sum()
Total
# Out:
# 'VEH01VEH02VEH03VEH04VEH05VEH06VEH07VEH08VEH09VEH10VEH11VEH12VEH13VEH14VEH15VEH16VEH17VEH18VEH19VEH20VEH21VEH22VEH23VEH24VEH25VEH26VEH27VEH28VEH29VEH30VEH31VEH32VEH33VEH34VEH35VEH36VEH37VEH38VEH39VEH40VEH41VEH42VEH43VEH44VEH45VEH46VEH47VEH48VEH49VEH50'
