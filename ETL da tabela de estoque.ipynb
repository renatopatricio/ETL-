# %% [markdown]
# # Fazendo o ETL da tabela de estoque

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('Tabela - Estoque.csv')
dados
# Out:
#       ID Produto Data atualização  Quantidade
# 0              1      1-jan.-2019         432
# 1              2      1-jan.-2019         412
# 2              3      1-jan.-2019         417
# 3              4      1-jan.-2019         438
# 4              5      1-jan.-2019         416
# ...          ...              ...         ...
# 1777          62      1-mar.-2021         597
# 1778          63      1-mar.-2021         520
# 1779          64      1-mar.-2021         545
# 1780          65      1-mar.-2021         621
# 1781          66      1-mar.-2021         609
#
# [1782 rows x 3 columns]

# %%
dados.value_counts("ID Produto")
# Out:
# ID Produto
# 1     27
# 50    27
# 36    27
# 37    27
# 38    27
#       ..
# 28    27
# 29    27
# 30    27
# 31    27
# 66    27
# Length: 66, dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1782 entries, 0 to 1781
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID Produto        1782 non-null   int64
#  1   Data atualização  1782 non-null   object
#  2   Quantidade        1782 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 41.9+ KB

# %%
dados.count
# Out:
# <bound method DataFrame.count of       ID Produto Data atualização  Quantidade
# 0              1      1-jan.-2019         432
# 1              2      1-jan.-2019         412
# 2              3      1-jan.-2019         417
# 3              4      1-jan.-2019         438
# 4              5      1-jan.-2019         416
# ...          ...              ...         ...
# 1777          62      1-mar.-2021         597
# 1778          63      1-mar.-2021         520
# 1779          64      1-mar.-2021         545
# 1780          65      1-mar.-2021         621
# 1781          66      1-mar.-2021         609
#
# [1782 rows x 3 columns]>

# %%
dados
# Out:
#       ID Produto Data atualização  Quantidade
# 0              1      1-jan.-2019         432
# 1              2      1-jan.-2019         412
# 2              3      1-jan.-2019         417
# 3              4      1-jan.-2019         438
# 4              5      1-jan.-2019         416
# ...          ...              ...         ...
# 1777          62      1-mar.-2021         597
# 1778          63      1-mar.-2021         520
# 1779          64      1-mar.-2021         545
# 1780          65      1-mar.-2021         621
# 1781          66      1-mar.-2021         609
#
# [1782 rows x 3 columns]

# %%
dados.value_counts("Quantidade")
# Out:
# Quantidade
# 433    27
# 449    26
# 407    26
# 409    26
# 418    26
#        ..
# 616     1
# 494     1
# 612     1
# 601     1
# 650     1
# Length: 233, dtype: int64

# %%
dados.sum(axis=1)
# Out:
# 0       433
# 1       414
# 2       420
# 3       442
# 4       421
#        ...
# 1777    659
# 1778    583
# 1779    609
# 1780    686
# 1781    675
# Length: 1782, dtype: int64

# %%
## o comando abaixo identifica quantos ID Produtos tem o valor do nulo

# %%
dados[dados['ID Produto'].isnull()].shape[0]
# Out:
# 0

# %%
dados[dados['Quantidade'].isnull()].shape[0]
# Out:
# 0

# %%
## quantidade total de produtos no estoque

# %%
Total = dados['Quantidade'].sum()
Total
# Out:
# 845625

# %%
## quantidade total de produtos cadastrados

# %%
dados['ID Produto'].count()
dados
# Out:
#       ID Produto Data atualização  Quantidade
# 0              1      1-jan.-2019         432
# 1              2      1-jan.-2019         412
# 2              3      1-jan.-2019         417
# 3              4      1-jan.-2019         438
# 4              5      1-jan.-2019         416
# ...          ...              ...         ...
# 1777          62      1-mar.-2021         597
# 1778          63      1-mar.-2021         520
# 1779          64      1-mar.-2021         545
# 1780          65      1-mar.-2021         621
# 1781          66      1-mar.-2021         609
#
# [1782 rows x 3 columns]

# %%
Total = dados['ID Produto'].sum()
Total
# Out:
# 59697

# %%
## quantidade de produtos cadastrados por data de atualização

# %%
dados.value_counts("Data atualização")
# Out:
# Data atualização
# 1-abr.-2019    66
# 1-jun.-2019    66
# 1-set.-2019    66
# 1-out.-2020    66
# 1-out.-2019    66
# 1-nov.-2020    66
# 1-nov.-2019    66
# 1-mar.-2021    66
# 1-mar.-2020    66
# 1-mar.-2019    66
# 1-mai.-2020    66
# 1-mai.-2019    66
# 1-jun.-2020    66
# 1-jul.-2020    66
# 1-abr.-2020    66
# 1-jul.-2019    66
# 1-jan.-2021    66
# 1-jan.-2020    66
# 1-jan.-2019    66
# 1-fev.-2021    66
# 1-fev.-2020    66
# 1-fev.-2019    66
# 1-dez.-2020    66
# 1-dez.-2019    66
# 1-ago.-2020    66
# 1-ago.-2019    66
# 1-set.-2020    66
# dtype: int64

# %%
Total = dados['Data atualização'].sum()
Total
# Out:
# '1-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-jan.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-20191-fev.-
# ...

# %%
dados.dtypes
# Out:
# ID Produto           int64
# Data atualização    object
# Quantidade           int64
# dtype: object

# %%
dados['Data atualização']
# Out:
# 0       1-jan.-2019
# 1       1-jan.-2019
# 2       1-jan.-2019
# 3       1-jan.-2019
# 4       1-jan.-2019
#            ...
# 1777    1-mar.-2021
# 1778    1-mar.-2021
# 1779    1-mar.-2021
# 1780    1-mar.-2021
# 1781    1-mar.-2021
# Name: Data atualização, Length: 1782, dtype: object

# %%
dtypes['Data atualização']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-35fb448ad25a> in <module>
# ----> 1 dtypes['Data atualização']
#
# NameError: name 'dtypes' is not defined

# %%
dados.value_counts("Data atualização")    
dados
# Out:
#       ID Produto Data atualização  Quantidade
# 0              1      1-jan.-2019         432
# 1              2      1-jan.-2019         412
# 2              3      1-jan.-2019         417
# 3              4      1-jan.-2019         438
# 4              5      1-jan.-2019         416
# ...          ...              ...         ...
# 1777          62      1-mar.-2021         597
# 1778          63      1-mar.-2021         520
# 1779          64      1-mar.-2021         545
# 1780          65      1-mar.-2021         621
# 1781          66      1-mar.-2021         609
#
# [1782 rows x 3 columns]
